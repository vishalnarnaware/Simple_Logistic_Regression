# %% [markdown]
# <a href="https://colab.research.google.com/github/vishalnarnaware/Simple_Logistic_Regression/blob/master/Simple_Logistic_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from math import exp

# Make a prediction with coefficients
def predict(row, coefficients):
	yhat = coefficients[0]
	for i in range(len(row)-1):
		yhat += coefficients[i + 1] * row[i]
	print(yhat,end=' ')
	return 1.0 / (1.0 + exp(-yhat))

# Estimate logistic regression coefficients using stochastic gradient descent
def coefficients_sgd(train, l_rate, n_epoch):
	coef = [0.0 for i in range(len(train[0]))]
	for epoch in range(n_epoch):
		sum_error = 0
		for row in train:
			yhat = predict(row, coef)
			error = row[-1] - yhat
			sum_error += error**2
			coef[0] = coef[0] + l_rate * error * yhat * (1.0 - yhat)
			for i in range(len(row)-1):
				coef[i + 1] = coef[i + 1] + l_rate * error * yhat * (1.0 - yhat) * row[i]
		print('\n>epoch=%d, lrate=%.3f, error=%.3f' % (epoch, l_rate, sum_error))
	return coef

# Calculate coefficients
dataset = [[2.7810836,2.550537003,0],
	[1.465489372,2.362125076,0],
	[3.396561688,4.400293529,0],
	[1.38807019,1.850220317,0],
	[3.06407232,3.005305973,0],
	[7.627531214,2.759262235,1],
	[5.332441248,2.088626775,1],
	[6.922596716,1.77106367,1],
	[8.675418651,-0.242068655,1],
	[7.673756466,3.508563011,1]]
l_rate = 0.3
n_epoch = 100
coef = coefficients_sgd(dataset, l_rate, n_epoch)
print(coef)
# Out:
# 0.0 -0.4162625951435882 -1.2800254034147436 -0.7245690659888779 -1.5103637879053067 -2.686460705223261 -1.15874951661374 0.4661634509818793 2.6095364663614853 2.0417464011534103
# >epoch=0, lrate=0.300, error=2.217
# 0.7158367745125118 -0.2076990403555084 -0.7355831380156718 -0.6653502505123532 -1.1795307024600106 -1.2075918140004422 0.9798963658206602 2.296446088497146 3.7821059507757835 2.236872035028477
# >epoch=1, lrate=0.300, error=1.613
# 0.4509036334671195 -0.5818474469279291 -1.1497195714855764 -0.7691187148170481 -1.157654299086727 -0.40660846205140433 1.60942742081716 2.8722518501168555 4.819580590587884 2.5404203140558215
# >epoch=2, lrate=0.300, error=1.113
# 0.2835319523711881 -0.8489689510660554 -1.42019082128291 -0.8640078710800696 -1.144957503623369 0.28115029683733495 1.506228002678481 2.9521973090445357 5.310031796123203 2.3882395078149843
# >epoch=3, lrate=0.300, error=0.827
# ...
